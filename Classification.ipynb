# %% [raw]
# pip install scikit-image

# %% [markdown]
# ## Image Recognition using SVM & PCA

# %%
import os
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np 
import pandas as pd

# %%
import matplotlib.pyplot as pt
# %matplotlib inline

# %%
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage import exposure
from skimage.color import rgb2gray

# %% [markdown]
# ## Import Images from Folder

# %%
Vijay = os.listdir('C:\\Users\\admin\\HARIDHARAN\\3\\Image dataset\\Vijay')

Atulya = os.listdir('C:\\Users\\admin\\HARIDHARAN\\3\\Image dataset\\Atulya_ravi')

Mamitha = os.listdir('C:\\Users\\admin\\HARIDHARAN\\3\\Image dataset\\Mamitha_bajju')

Priya = os.listdir('C:\\Users\\admin\\HARIDHARAN\\3\\Image dataset\\Priya_Bhavani_Shankar')

Rashmika = os.listdir('C:\\Users\\admin\\HARIDHARAN\\3\\Image dataset\\Rashmika')

Samantha = os.listdir('C:\\Users\\admin\\HARIDHARAN\\3\\Image dataset\\Samantha')

Sreeleela = os.listdir('C:\\Users\\admin\\HARIDHARAN\\3\\Image dataset\\Sreeleela')

Trisha = os.listdir('C:\\Users\\admin\\HARIDHARAN\\3\\Image dataset\\Trisha')

Sethupathi = os.listdir('C:\\Users\\admin\\HARIDHARAN\\3\\Image dataset\\Vijay_Sethupathi')

Jhanvi = os.listdir('C:\\Users\\admin\\HARIDHARAN\\3\\Image dataset\\Jhanvi_Kapoor')

# %% [markdown]
# ## Reading Images as matrix

# %%
limit = 10
priya_images = [None]*limit
samantha_images = [None]*limit
sreeleela_images = [None]*limit
vijay_images = [None]*limit
mamitha_images = [None]*limit
rashmika_images = [None]*limit
trisha_images = [None]*limit
sethupathi_images = [None]*limit

c=0

#for i in Priya:
#    if c<limit:
#        priya_images[c] = imread("C:\\Users\\admin\\HARIDHARAN\\3\\Image dataset\\Priya_Bhavani_Shankar\\"+i)
#        c+=1
#    else:
#        break

while c<limit:
    priya_images[c] = imread(f"C:\\Users\\admin\\HARIDHARAN\\3\\Image dataset\\Priya_Bhavani_Shankar\\{Priya[c]}")
    samantha_images[c] = imread(f'C:\\Users\\admin\\HARIDHARAN\\3\\Image dataset\\Samantha\\{Samantha[c]}')
    sreeleela_images[c] = imread(f'C:\\Users\\admin\\HARIDHARAN\\3\\Image dataset\\Sreeleela\\{Sreeleela[c]}')
    vijay_images[c] = imread(f'C:\\Users\\admin\\HARIDHARAN\\3\\Image dataset\\Vijay\\{Vijay[c]}')
    mamitha_images[c] = imread(f'C:\\Users\\admin\\HARIDHARAN\\3\\Image dataset\\Mamitha_bajju\\{Mamitha[c]}')
    rashmika_images[c] = imread(f'C:\\Users\\admin\\HARIDHARAN\\3\\Image dataset\\Rashmika\\{Rashmika[c]}')
    trisha_images[c] = imread(f'C:\\Users\\admin\\HARIDHARAN\\3\\Image dataset\\Trisha\\{Trisha[c]}')
    sethupathi_images[c] = imread(f'C:\\Users\\admin\\HARIDHARAN\\3\\Image dataset\\Vijay_Sethupathi\\{Sethupathi[c]}')
    c+=1

# %%
imshow(sethupathi_images[3])

# %%
pt.show()

# %% [markdown]
# ## Convert To GrayScale

# %%
priya_gray = [None]*limit
samantha_gray = [None]*limit
sreeleela_gray = [None]*limit
vijay_gray = [None]*limit
mamitha_gray = [None]*limit
rashmika_gray = [None]*limit
trisha_gray = [None]*limit
sethupathi_gray = [None]*limit

c=0

while c<limit:
    priya_gray[c] = rgb2gray(priya_images[c])
    samantha_gray[c] = rgb2gray(samantha_images[c])
    sreeleela_gray[c] = rgb2gray(sreeleela_images[c])
    vijay_gray[c] = rgb2gray(vijay_images[c])
    mamitha_gray[c] = rgb2gray(mamitha_images[c])
    rashmika_gray[c] = rgb2gray(rashmika_images[c])
    trisha_gray[c] = rgb2gray(trisha_images[c])
    sethupathi_gray[c] = rgb2gray(sethupathi_images[c])
    c+=1

# %%
imshow(sethupathi_gray[3])

# %%
pt.show()

# %%
sethupathi_gray[3].shape
# Out:
# (235, 177)

# %%
imshow(vijay_gray[4])

# %%
pt.show()

# %% [markdown]
# ## Reshape the image into 512 x 512

# %%
priya_resize = [None]*limit
samantha_resize = [None]*limit
sreeleela_resize = [None]*limit
vijay_resize = [None]*limit
mamitha_resize = [None]*limit
rashmika_resize = [None]*limit
trisha_resize = [None]*limit
sethupathi_resize = [None]*limit

c=0

while c<limit:
    priya_resize[c] = resize(priya_gray[c],(512,512))
    samantha_resize[c] = resize(samantha_gray[c],(512,512))
    sreeleela_resize[c] = resize(sreeleela_gray[c],(512,512))
    vijay_resize[c] = resize(vijay_gray[c],(512,512))
    mamitha_resize[c] = resize(mamitha_gray[c],(512,512))
    rashmika_resize[c] = resize(rashmika_gray[c],(512,512))
    trisha_resize[c] = resize(trisha_gray[c],(512,512))
    sethupathi_resize[c] = resize(sethupathi_gray[c],(512,512))
    c+=1

# %%
imshow(sethupathi_resize[3])

# %%
pt.show()

# %%
sethupathi_resize[3].shape
# Out:
# (512, 512)

# %% [markdown]
# ## Matrix To Vector Conversion

# %% [markdown]
# ### A. Find the len of the Images

# %%
len_of_images = len(priya_resize)

# %% [markdown]
# ### B. Flattening the Image

# %%
ima_size = sethupathi_resize[3].shape

# %%
ima_size
# Out:
# (512, 512)

# %%
flatten_size = ima_size[0] * ima_size[1]

# %%
flatten_size
# Out:
# 262144

# %%
for i in range(len_of_images):
    priya_resize[i] = np.ndarray.flatten(priya_resize[i]).reshape(flatten_size)
    samantha_resize[i] = np.ndarray.flatten(samantha_resize[i]).reshape(flatten_size)
    sreeleela_resize[i] = np.ndarray.flatten(sreeleela_resize[i]).reshape(flatten_size)
    vijay_resize[i] = np.ndarray.flatten(vijay_resize[i]).reshape(flatten_size)
    mamitha_resize[i] = np.ndarray.flatten(mamitha_resize[i]).reshape(flatten_size)
    rashmika_resize[i] = np.ndarray.flatten(rashmika_resize[i]).reshape(flatten_size)
    trisha_resize[i] = np.ndarray.flatten(trisha_resize[i]).reshape(flatten_size)
    sethupathi_resize[i] = np.ndarray.flatten(sethupathi_resize[i]).reshape(flatten_size)

# %%
priya_resize = np.dstack(priya_resize)
samantha_resize = np.dstack(samantha_resize)
sreeleela_resize = np.dstack(sreeleela_resize)
vijay_resize = np.dstack(vijay_resize)
mamitha_resize = np.dstack(mamitha_resize)
rashmika_resize = np.dstack(rashmika_resize)
trisha_resize = np.dstack(trisha_resize)
sethupathi_resize = np.dstack(sethupathi_resize)

# %%
priya_resize

# %%
priya_resize.shape
# Out:
# (1, 262144, 10)

# %%
priya_resize = np.rollaxis(priya_resize, axis=2, start=0)
samantha_resize = np.rollaxis(samantha_resize, axis=2, start=0)
sreeleela_resize = np.rollaxis(sreeleela_resize, axis=2, start=0)
vijay_resize = np.rollaxis(vijay_resize, axis=2, start=0)
mamitha_resize = np.rollaxis(mamitha_resize, axis=2, start=0)
rashmika_resize = np.rollaxis(rashmika_resize, axis=2, start=0)
trisha_resize = np.rollaxis(trisha_resize, axis=2, start=0)
sethupathi_resize = np.rollaxis(sethupathi_resize, axis=2, start=0)

# %%
priya_resize.shape
# Out:
# (10, 1, 262144)

# %%
priya_resize = priya_resize.reshape(len_of_images, flatten_size)
samantha_resize = samantha_resize.reshape(len_of_images, flatten_size)
sreeleela_resize = sreeleela_resize.reshape(len_of_images, flatten_size)
vijay_resize = vijay_resize.reshape(len_of_images, flatten_size)
mamitha_resize = mamitha_resize.reshape(len_of_images, flatten_size)
rashmika_resize = rashmika_resize.reshape(len_of_images, flatten_size)
trisha_resize = trisha_resize.reshape(len_of_images, flatten_size)
sethupathi_resize = sethupathi_resize.reshape(len_of_images, flatten_size)

# %%
priya_resize.shape
# Out:
# (10, 262144)

# %% [markdown]
# ## Convert the dataset into Data frame

# %%
priya_resize = pd.DataFrame(priya_resize)
samantha_resize = pd.DataFrame(samantha_resize)
sreeleela_resize = pd.DataFrame(sreeleela_resize)
vijay_resize = pd.DataFrame(vijay_resize)
mamitha_resize = pd.DataFrame(mamitha_resize)
rashmika_resize = pd.DataFrame(rashmika_resize)
trisha_resize = pd.DataFrame(trisha_resize)
sethupathi_resize = pd.DataFrame(sethupathi_resize)

# %% [markdown]
# ## Add label to the dataset

# %%
priya_data["label"]
samantha_data["label"]
sreeleela_data["label"]
vijay_data["label"]
mamitha_data["label"]
rashmika_data["label"]
trisha_data["label"]
sethupathi_data["label"]
